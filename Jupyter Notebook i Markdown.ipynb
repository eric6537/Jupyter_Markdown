# %% [markdown]
# # S01 T01: Jupyter Notebook Markdown
# ### Descripció
# >_Comencem a familiaritzar-nos amb Python mitjançant
# >l'entorn de treball "Jupyter Notebook" !!!
# >Comencem amb uns quants exercicis bàsics_
# ***
# #### Objectius
# * Crear variables
# * Operacions matemàtiques
# + Transforma amb càsting
# + Tècniques amb Strings
# - Booleans

# %% [markdown]
# ## Exercici 1
# - [x] Instal·lar el programa Anaconda amb Python 3 i Jupyter Notebook.

# %% [markdown]
# ## Exercici 2
# - [x] Familiaritzar-se amb el llenguatge Markdown.
# - [x] Executar alguns calculs senzills.
#
# Gràfic fet amb les dades de l'Iris Data Set de R.A.Fisher (es pot trobar a https://archive.ics.uci.edu/ml/datasets/Iris >> Download: Data Folder >> iris.data)

# %%
#Importar llibreries


#Consultar informació de les dades
#info = open("iris.names","r")
#print(info.read())
#info.close()

#Obrir l'arxiu com un dataset
data = pd.read_csv("iris.data",sep=",")

#Agafar els valors de la x i la y (columnes de longitud i amplada del pètal)
x = data.iloc[:,2]
y = data.iloc[:,3]

#Fer el grafic
plt.plot(x,y,".r")
plt.xlabel("longitud del petal en cm")
plt.ylabel("amplada del petal en cm")
plt.title("Relació entre la longitud i l'amplada dels pètals")
# Out:
# Text(0.5, 1.0, "Relació entre la longitud i l'amplada dels pètals")

# %%
#Grafic de prova
import numpy as np

xpoints = np.array([1,6])
ypoints = np.array([3,8,1,10])

plt.plot(ypoints,'*-.g',ms=20,mec="c",mfc="c")
plt.title("Prova")
plt.show()

# %% [markdown]
# <span style="color:green;font-family:'arial narrow';font-weight:700;font-size:22px">
#     Exercici 3
# </span>
#
# - [x] Crear títols, llistes, canviar estil de la lletra i afegir imatges.
#
#
#
# [<img src="https://www.nasa.gov/sites/default/files/styles/full_width_feature/public/thumbnails/image/jpegpia23121.jpeg" width="500">](https://www.nasa.gov/image-feature/space-butterfly?node=249506&feed=62&id=478775)
